# %% [markdown]
# # Task 1 — Exploratory Data Analysis
# UCI Heart Disease Dataset (Cleveland subset)
#
# This notebook runs `eda.py` and shows the analysis.

# %% [markdown]
# ## Run the EDA script

# %%
# %run eda.py
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\IPython\core\magics\execution.py:728, in ExecutionMagics.run(self, parameter_s, runner, file_finder)
#     727     fpath = arg_lst[0]
# --> 728     filename = file_finder(fpath)
#     729 except IndexError as e:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\IPython\utils\path.py:90, in get_py_filename(name)
#      89         return py_name
# ---> 90 raise IOError("File `%r` not found." % name)
#
# OSError: File `'eda.py'` not found.
#
# The above exception was the direct cause of the following exception:
#
# Exception                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 get_ipython().run_line_magic('run', 'eda.py')
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\IPython\core\interactiveshell.py:2504, in InteractiveShell.run_line_magic(self, magic_name, line, _stack_depth)
#    2502     kwargs['local_ns'] = self.get_local_scope(stack_depth)
#    2503 with self.builtin_trap:
# -> 2504     result = fn(*args, **kwargs)
#    2506 # The code below prevents the output from being displayed
#    2507 # when using magics with decorator @output_can_be_silenced
#    2508 # when the last Python token in the expression is a ';'.
#    2509 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\IPython\core\magics\execution.py:739, in ExecutionMagics.run(self, parameter_s, runner, file_finder)
#     737     if os.name == 'nt' and re.match(r"^'.*'$",fpath):
#     738         warn('For Windows, use double quotes to wrap a filename: %run "mypath\\myfile.py"')
# --> 739     raise Exception(msg) from e
#     740 except TypeError:
#     741     if fpath in sys.meta_path:
#
# Exception: File `'eda.py'` not found.

# %% [markdown]
# ## 1. Dataset overview

# %%
df.shape

# %%
df.head()

# %%
df.dtypes

# %%
df.describe()

# %% [markdown]
# ## 2. Missing values and duplicates

# %%
df.isna().sum()

# %%
df.duplicated().sum()

# %% [markdown]
# ## 3. Class balance

# %%
df[target].value_counts()

# %%
from IPython.display import Image
Image('class_balance.png')

# %% [markdown]
# ## 4. Boxplots of continuous features by class

# %%
Image('boxplots.png')

# %% [markdown]
# ## 5. Histograms of continuous features by class

# %%
Image('histograms.png')

# %% [markdown]
# ## 6. Count plots for discrete features

# %%
Image('countplots.png')

# %% [markdown]
# ## 7. Correlation heatmap (Spearman)

# %%
Image('correlation.png')

# %%
corr[target].drop(target).abs().sort_values(ascending=False)

# %% [markdown]
# ## 8. PCA (2D)

# %%
Image('pca.png')

# %%
pca.explained_variance_ratio_

# %% [markdown]
# ## Notes for modeling
#
# - Missing values exist in `ca` and `thal` → handle inside CV folds
# - Class balance → use stratified folds and metrics like MCC, balanced accuracy, F1
# - Top correlated features with target: `thalach`, `oldpeak`, `cp`, `exang`, `ca`, `thal`
# - Continuous features need scaling (for LR, LDA, GNB)
# - Categorical features need encoding
