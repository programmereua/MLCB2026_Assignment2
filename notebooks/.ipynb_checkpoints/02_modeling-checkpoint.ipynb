# %% [markdown]
# # Task 3 — Nested Cross-Validation
# **MLCB 2026 — Assignment #2**
# Heart Disease Classification
#
#  We will use  the `RepeatedNestedCV` class defined in `eda.py` to evaluate seven classification algorithms on the Cleveland Heart Disease dataset.

# %% [markdown]
# ## Setup

# %%
import sys
sys.path.append("../src")
import eda_utils as eda
import nested_cv as ncv
import pandas as pd

df = eda.load_data("../data/students_dataset.csv")
X = df[eda.features]
y = df[eda.target]

print("X shape:", X.shape)
print("y distribution:", y.value_counts().to_dict())
# Out:
# X shape: (242, 13)
# y distribution: {0: 131, 1: 111}

# %% [markdown]
# ## Define the seven algorithms
# Logistic Regression (Elastic Net), Gaussian NB, LDA, Random Forest, LightGBM, XGBoost, CatBoost.
#
# Base configuration is set here — Optuna only tunes the hyperparameters we expose in the search spaces below.

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.ensemble import RandomForestClassifier
from lightgbm import LGBMClassifier
from xgboost import XGBClassifier
from catboost import CatBoostClassifier

estimators = {
    "LR":       LogisticRegression(penalty="elasticnet", solver="saga",
                                   l1_ratio=0.5, max_iter=2000, random_state=42),
    "GNB":      GaussianNB(),
    "LDA":      LinearDiscriminantAnalysis(),
    "RF":       RandomForestClassifier(random_state=42),
    "LightGBM": LGBMClassifier(random_state=42, verbose=-1),
    "XGBoost":  XGBClassifier(random_state=42, eval_metric="logloss", verbosity=0),
    "CatBoost": CatBoostClassifier(random_state=42, verbose=0)
}

# %% [markdown]
# ## Hyperparameter spaces
# Each function takes an Optuna `trial` and returns only the parameters we want to tune. The base estimator's other params (solver, random_state, etc.) are preserved via `clone + set_params`.

# %%
def lr_space(trial):
    return {
        "C":        trial.suggest_float("C", 1e-3, 10.0, log=True),
        "l1_ratio": trial.suggest_float("l1_ratio", 0.0, 1.0)
    }

def gnb_space(trial):
    return {"var_smoothing": trial.suggest_float("var_smoothing", 1e-12, 1e-6, log=True)}

def lda_space(trial):
    solver = trial.suggest_categorical("solver", ["svd", "lsqr"])
    params = {"solver": solver}
    if solver == "lsqr":
        params["shrinkage"] = trial.suggest_float("shrinkage", 0.0, 1.0)
    return params

def rf_space(trial):
    return {
        "n_estimators":      trial.suggest_int("n_estimators", 100, 500),
        "max_depth":         trial.suggest_int("max_depth", 3, 20),
        "min_samples_split": trial.suggest_int("min_samples_split", 2, 10)
    }

def lgbm_space(trial):
    return {
        "n_estimators":  trial.suggest_int("n_estimators", 100, 500),
        "learning_rate": trial.suggest_float("learning_rate", 0.01, 0.3, log=True),
        "num_leaves":    trial.suggest_int("num_leaves", 15, 127)
    }

def xgb_space(trial):
    return {
        "n_estimators":  trial.suggest_int("n_estimators", 100, 500),
        "learning_rate": trial.suggest_float("learning_rate", 0.01, 0.3, log=True),
        "max_depth":     trial.suggest_int("max_depth", 3, 10)
    }

def cat_space(trial):
    return {
        "iterations":    trial.suggest_int("iterations", 100, 500),
        "learning_rate": trial.suggest_float("learning_rate", 0.01, 0.3, log=True),
        "depth":         trial.suggest_int("depth", 3, 10)
    }

param_spaces = {
    "LR":       lr_space,
    "GNB":      gnb_space,
    "LDA":      lda_space,
    "RF":       rf_space,
    "LightGBM": lgbm_space,
    "XGBoost":  xgb_space,
    "CatBoost": cat_space
}

# %% [markdown]
# ## Step 3.2a — Baseline (no tuning)
# Fair comparison across algorithms with default hyperparameters.

# %%
rncv = ncv.RepeatedNestedCV(
    estimators=estimators,
    param_spaces=param_spaces,
    R=10, N=5, K=3,
    n_trials=50,
    random_state=42
)

baseline_results = rncv.run_baseline(X, y)
# Out:
# [Baseline] LR
#
# [Baseline] GNB
#
# [Baseline] LDA
#
# [Baseline] RF
#
# [Baseline] LightGBM
#
# [Baseline] XGBoost
#
# [Baseline] CatBoost

# %%
rncv.summary(baseline_results)
# Out:
#            MCC_median          MCC_CI  AUC_median          AUC_CI  BA_median  \
# Algorithm
# LR              0.631  [0.596, 0.670]       0.891  [0.878, 0.908]      0.811
# GNB             0.654  [0.610, 0.678]       0.893  [0.878, 0.910]      0.823
# LDA             0.664  [0.623, 0.680]       0.895  [0.881, 0.911]      0.823
# RF              0.600  [0.546, 0.628]       0.877  [0.858, 0.892]      0.790
# LightGBM        0.553  [0.538, 0.590]       0.856  [0.837, 0.868]      0.775
# XGBoost         0.569  [0.518, 0.591]       0.859  [0.837, 0.874]      0.779
# CatBoost        0.581  [0.549, 0.625]       0.878  [0.865, 0.893]      0.781
#
#                     BA_CI  F1_median           F1_CI  Recall_median  \
# Algorithm
# LR         [0.794, 0.831]      0.786  [0.776, 0.816]          0.773
# GNB        [0.798, 0.844]      0.809  [0.773, 0.828]          0.818
# LDA        [0.806, 0.841]      0.804  [0.780, 0.826]          0.773
# RF         [0.770, 0.809]      0.772  [0.738, 0.791]          0.727
# LightGBM   [0.766, 0.793]      0.750  [0.739, 0.773]          0.727
# XGBoost    [0.759, 0.794]      0.758  [0.744, 0.780]          0.773
# CatBoost   [0.774, 0.809]      0.766  [0.750, 0.785]          0.773
#
#                 Recall_CI  Specificity_median  Specificity_CI  \
# Algorithm
# LR         [0.727, 0.818]               0.885  [0.846, 0.885]
# GNB        [0.739, 0.818]               0.846  [0.846, 0.885]
# LDA        [0.733, 0.800]               0.885  [0.852, 0.889]
# RF         [0.711, 0.773]               0.846  [0.811, 0.885]
# LightGBM   [0.696, 0.773]               0.811  [0.793, 0.849]
# XGBoost    [0.739, 0.778]               0.808  [0.769, 0.830]
# CatBoost   [0.727, 0.796]               0.846  [0.808, 0.865]
#
#            Precision_median    Precision_CI  PRAUC_median        PRAUC_CI
# Algorithm
# LR                    0.838  [0.805, 0.854]         0.895  [0.867, 0.911]
# GNB                   0.833  [0.805, 0.850]         0.886  [0.856, 0.900]
# LDA                   0.846  [0.815, 0.863]         0.895  [0.873, 0.914]
# RF                    0.800  [0.789, 0.818]         0.872  [0.859, 0.890]
# LightGBM              0.786  [0.751, 0.801]         0.860  [0.834, 0.870]
# XGBoost               0.773  [0.741, 0.792]         0.860  [0.844, 0.871]
# CatBoost              0.800  [0.762, 0.817]         0.879  [0.864, 0.905]

# %% [markdown]
# LDA achieved the highest median MCC of 0.664 [0.623, 0.693], followed closely by GNB (0.654) and LR (0.631). Notably, linear classifiers outperformed ensemble tree-based methods on this dataset, likely due to the small sample size (n=242) and the relatively linear decision boundary suggested by the Spearman correlations. The 95% bootstrap CIs of LDA and GNB overlap, however LDA consistently shows higher median values across MCC, AUC, and Precision, making it the selected winner algorithm.

# %% [markdown]
# ## Step 3.2b Full repeated nested CV with hyperparameter tuning
# R = 10 repetitions, 5 outer folds, 3 inner folds, 50 Optuna trials per outer fold.

# %%
rncv_results = rncv.run(X, y)
# Out:
# [rnCV] LR
#   rep 1 / fold 1 -- MCC=0.633
#   rep 1 / fold 2 -- MCC=0.596
#   rep 1 / fold 3 -- MCC=0.669
#   rep 1 / fold 4 -- MCC=0.624
#   rep 1 / fold 5 -- MCC=0.706
#   rep 2 / fold 1 -- MCC=0.838
#   rep 2 / fold 2 -- MCC=0.674
#   rep 2 / fold 3 -- MCC=0.669
#   rep 2 / fold 4 -- MCC=0.748
#   rep 2 / fold 5 -- MCC=0.367
#   rep 3 / fold 1 -- MCC=0.594
#   rep 3 / fold 2 -- MCC=0.711
#   rep 3 / fold 3 -- MCC=0.832
#   rep 3 / fold 4 -- MCC=0.643
#   rep 3 / fold 5 -- MCC=0.624
#   rep 4 / fold 1 -- MCC=0.756
#   rep 4 / fold 2 -- MCC=0.711
#   rep 4 / fold 3 -- MCC=0.503
#   rep 4 / fold 4 -- MCC=0.718
#   rep 4 / fold 5 -- MCC=0.538
#   rep 5 / fold 1 -- MCC=0.594
#   rep 5 / fold 2 -- MCC=0.795
#   rep 5 / fold 3 -- MCC=0.753
#   rep 5 / fold 4 -- MCC=0.462
#   rep 5 / fold 5 -- MCC=0.669
#   rep 6 / fold 1 -- MCC=0.762
#   rep 6 / fold 2 -- MCC=0.631
#   rep 6 / fold 3 -- MCC=0.606
#   rep 6 / fold 4 -- MCC=0.706
#   rep 6 / fold 5 -- MCC=0.541
#   rep 7 / fold 1 -- MCC=0.556
#   rep 7 / fold 2 -- MCC=0.918
#   rep 7 / fold 3 -- MCC=0.664
#   rep 7 / fold 4 -- MCC=0.664
#   rep 7 / fold 5 -- MCC=0.410
#   rep 8 / fold 1 -- MCC=0.762
#   rep 8 / fold 2 -- MCC=0.419
#   rep 8 / fold 3 -- MCC=0.631
#   rep 8 / fold 4 -- MCC=0.580
#   rep 8 / fold 5 -- MCC=0.580
#   rep 9 / fold 1 -- MCC=0.838
#   rep 9 / fold 2 -- MCC=0.635
#   rep 9 / fold 3 -- MCC=0.410
#   rep 9 / fold 4 -- MCC=0.756
#   rep 9 / fold 5 -- MCC=0.580
#   rep 10 / fold 1 -- MCC=0.550
#   rep 10 / fold 2 -- MCC=0.807
#   rep 10 / fold 3 -- MCC=0.583
#   rep 10 / fold 4 -- MCC=0.680
#   rep 10 / fold 5 -- MCC=0.624
#
# [rnCV] GNB
#   rep 1 / fold 1 -- MCC=0.713
#   rep 1 / fold 2 -- MCC=0.589
#   rep 1 / fold 3 -- MCC=0.669
#   rep 1 / fold 4 -- MCC=0.669
#   rep 1 / fold 5 -- MCC=0.541
#   rep 2 / fold 1 -- MCC=0.836
#   rep 2 / fold 2 -- MCC=0.794
#   rep 2 / fold 3 -- MCC=0.580
#   rep 2 / fold 4 -- MCC=0.753
#   rep 2 / fold 5 -- MCC=0.367
#   rep 3 / fold 1 -- MCC=0.678
#   rep 3 / fold 2 -- MCC=0.670
#   rep 3 / fold 3 -- MCC=0.799
#   rep 3 / fold 4 -- MCC=0.553
#   rep 3 / fold 5 -- MCC=0.669
#   rep 4 / fold 1 -- MCC=0.715
#   rep 4 / fold 2 -- MCC=0.711
#   rep 4 / fold 3 -- MCC=0.410
#   rep 4 / fold 4 -- MCC=0.749
#   rep 4 / fold 5 -- MCC=0.537
#   rep 5 / fold 1 -- MCC=0.590
#   rep 5 / fold 2 -- MCC=0.638
#   rep 5 / fold 3 -- MCC=0.753
#   rep 5 / fold 4 -- MCC=0.462
#   rep 5 / fold 5 -- MCC=0.580
#   rep 6 / fold 1 -- MCC=0.631
#   rep 6 / fold 2 -- MCC=0.567
#   rep 6 / fold 3 -- MCC=0.643
#   rep 6 / fold 4 -- MCC=0.706
#   rep 6 / fold 5 -- MCC=0.664
#   rep 7 / fold 1 -- MCC=0.590
#   rep 7 / fold 2 -- MCC=0.844
#   rep 7 / fold 3 -- MCC=0.706
#   rep 7 / fold 4 -- MCC=0.706
#   rep 7 / fold 5 -- MCC=0.495
#   rep 8 / fold 1 -- MCC=0.678
#   rep 8 / fold 2 -- MCC=0.635
#   rep 8 / fold 3 -- MCC=0.643
#   rep 8 / fold 4 -- MCC=0.624
#   rep 8 / fold 5 -- MCC=0.623
#   rep 9 / fold 1 -- MCC=0.715
#   rep 9 / fold 2 -- MCC=0.711
#   rep 9 / fold 3 -- MCC=0.452
#   rep 9 / fold 4 -- MCC=0.706
#   rep 9 / fold 5 -- MCC=0.580
#   rep 10 / fold 1 -- MCC=0.590
#   rep 10 / fold 2 -- MCC=0.797
#   rep 10 / fold 3 -- MCC=0.537
#   rep 10 / fold 4 -- MCC=0.749
#   rep 10 / fold 5 -- MCC=0.502
#
# [rnCV] LDA
#   rep 1 / fold 1 -- MCC=0.715
#   rep 1 / fold 2 -- MCC=0.558
#   rep 1 / fold 3 -- MCC=0.623
#   rep 1 / fold 4 -- MCC=0.624
#   rep 1 / fold 5 -- MCC=0.706
#   rep 2 / fold 1 -- MCC=0.838
#   rep 2 / fold 2 -- MCC=0.674
#   rep 2 / fold 3 -- MCC=0.623
#   rep 2 / fold 4 -- MCC=0.706
#   rep 2 / fold 5 -- MCC=0.367
#   rep 3 / fold 1 -- MCC=0.594
#   rep 3 / fold 2 -- MCC=0.711
#   rep 3 / fold 3 -- MCC=0.792
#   rep 3 / fold 4 -- MCC=0.643
#   rep 3 / fold 5 -- MCC=0.664
#   rep 4 / fold 1 -- MCC=0.800
#   rep 4 / fold 2 -- MCC=0.670
#   rep 4 / fold 3 -- MCC=0.503
#   rep 4 / fold 4 -- MCC=0.749
#   rep 4 / fold 5 -- MCC=0.538
#   rep 5 / fold 1 -- MCC=0.678
#   rep 5 / fold 2 -- MCC=0.767
#   rep 5 / fold 3 -- MCC=0.753
#   rep 5 / fold 4 -- MCC=0.462
#   rep 5 / fold 5 -- MCC=0.669
#   rep 6 / fold 1 -- MCC=0.762
#   rep 6 / fold 2 -- MCC=0.631
#   rep 6 / fold 3 -- MCC=0.643
#   rep 6 / fold 4 -- MCC=0.706
#   rep 6 / fold 5 -- MCC=0.541
#   rep 7 / fold 1 -- MCC=0.510
#   rep 7 / fold 2 -- MCC=0.918
#   rep 7 / fold 3 -- MCC=0.756
#   rep 7 / fold 4 -- MCC=0.664
#   rep 7 / fold 5 -- MCC=0.329
#   rep 8 / fold 1 -- MCC=0.762
#   rep 8 / fold 2 -- MCC=0.589
#   rep 8 / fold 3 -- MCC=0.631
#   rep 8 / fold 4 -- MCC=0.580
#   rep 8 / fold 5 -- MCC=0.580
#   rep 9 / fold 1 -- MCC=0.838
#   rep 9 / fold 2 -- MCC=0.753
#   rep 9 / fold 3 -- MCC=0.410
#   rep 9 / fold 4 -- MCC=0.756
#   rep 9 / fold 5 -- MCC=0.497
#   rep 10 / fold 1 -- MCC=0.550
#   rep 10 / fold 2 -- MCC=0.837
#   rep 10 / fold 3 -- MCC=0.538
#   rep 10 / fold 4 -- MCC=0.680
#   rep 10 / fold 5 -- MCC=0.585
#
# [rnCV] RF
#   rep 1 / fold 1 -- MCC=0.676
#   rep 1 / fold 2 -- MCC=0.684
#   rep 1 / fold 3 -- MCC=0.680
#   rep 1 / fold 4 -- MCC=0.624
#   rep 1 / fold 5 -- MCC=0.580
#   rep 2 / fold 1 -- MCC=0.754
#   rep 2 / fold 2 -- MCC=0.629
#   rep 2 / fold 3 -- MCC=0.538
#   rep 2 / fold 4 -- MCC=0.709
#   rep 2 / fold 5 -- MCC=0.369
#   rep 3 / fold 1 -- MCC=0.510
#   rep 3 / fold 2 -- MCC=0.753
#   rep 3 / fold 3 -- MCC=0.753
#   rep 3 / fold 4 -- MCC=0.643
#   rep 3 / fold 5 -- MCC=0.580
#   rep 4 / fold 1 -- MCC=0.672
#   rep 4 / fold 2 -- MCC=0.588
#   rep 4 / fold 3 -- MCC=0.503
#   rep 4 / fold 4 -- MCC=0.664
#   rep 4 / fold 5 -- MCC=0.538
#   rep 5 / fold 1 -- MCC=0.633
#   rep 5 / fold 2 -- MCC=0.685
#   rep 5 / fold 3 -- MCC=0.585
#   rep 5 / fold 4 -- MCC=0.380
#   rep 5 / fold 5 -- MCC=0.583
#   rep 6 / fold 1 -- MCC=0.717
#   rep 6 / fold 2 -- MCC=0.505
#   rep 6 / fold 3 -- MCC=0.680
#   rep 6 / fold 4 -- MCC=0.538
#   rep 6 / fold 5 -- MCC=0.502
#   rep 7 / fold 1 -- MCC=0.351
#   rep 7 / fold 2 -- MCC=0.920
#   rep 7 / fold 3 -- MCC=0.709
#   rep 7 / fold 4 -- MCC=0.580
#   rep 7 / fold 5 -- MCC=0.418
#   rep 8 / fold 1 -- MCC=0.653
#   rep 8 / fold 2 -- MCC=0.461
#   rep 8 / fold 3 -- MCC=0.624
#   rep 8 / fold 4 -- MCC=0.495
#   rep 8 / fold 5 -- MCC=0.623
#   rep 9 / fold 1 -- MCC=0.800
#   rep 9 / fold 2 -- MCC=0.674
#   rep 9 / fold 3 -- MCC=0.452
#   rep 9 / fold 4 -- MCC=0.794
#   rep 9 / fold 5 -- MCC=0.538
#   rep 10 / fold 1 -- MCC=0.590
#   rep 10 / fold 2 -- MCC=0.684
#   rep 10 / fold 3 -- MCC=0.583
#   rep 10 / fold 4 -- MCC=0.583
#   rep 10 / fold 5 -- MCC=0.643
#
# [rnCV] LightGBM
#   rep 1 / fold 1 -- MCC=0.715
#   rep 1 / fold 2 -- MCC=0.503
#   rep 1 / fold 3 -- MCC=0.622
#   rep 1 / fold 4 -- MCC=0.580
#   rep 1 / fold 5 -- MCC=0.580
#   rep 2 / fold 1 -- MCC=0.713
#   rep 2 / fold 2 -- MCC=0.596
#   rep 2 / fold 3 -- MCC=0.452
#   rep 2 / fold 4 -- MCC=0.664
#   rep 2 / fold 5 -- MCC=0.410
#   rep 3 / fold 1 -- MCC=0.550
#   rep 3 / fold 2 -- MCC=0.588
#   rep 3 / fold 3 -- MCC=0.608
#   rep 3 / fold 4 -- MCC=0.591
#   rep 3 / fold 5 -- MCC=0.453
#   rep 4 / fold 1 -- MCC=0.713
#   rep 4 / fold 2 -- MCC=0.631
#   rep 4 / fold 3 -- MCC=0.538
#   rep 4 / fold 4 -- MCC=0.669
#   rep 4 / fold 5 -- MCC=0.553
#   rep 5 / fold 1 -- MCC=0.594
#   rep 5 / fold 2 -- MCC=0.593
#   rep 5 / fold 3 -- MCC=0.502
#   rep 5 / fold 4 -- MCC=0.422
#   rep 5 / fold 5 -- MCC=0.538
#   rep 6 / fold 1 -- MCC=0.838
#   rep 6 / fold 2 -- MCC=0.485
#   rep 6 / fold 3 -- MCC=0.474
#   rep 6 / fold 4 -- MCC=0.580
#   rep 6 / fold 5 -- MCC=0.558
#   rep 7 / fold 1 -- MCC=0.510
#   rep 7 / fold 2 -- MCC=0.837
#   rep 7 / fold 3 -- MCC=0.706
#   rep 7 / fold 4 -- MCC=0.706
#   rep 7 / fold 5 -- MCC=0.457
#   rep 8 / fold 1 -- MCC=0.641
#   rep 8 / fold 2 -- MCC=0.520
#   rep 8 / fold 3 -- MCC=0.502
#   rep 8 / fold 4 -- MCC=0.410
#   rep 8 / fold 5 -- MCC=0.622
#   rep 9 / fold 1 -- MCC=0.800
#   rep 9 / fold 2 -- MCC=0.505
#   rep 9 / fold 3 -- MCC=0.495
#   rep 9 / fold 4 -- MCC=0.794
#   rep 9 / fold 5 -- MCC=0.413
#   rep 10 / fold 1 -- MCC=0.466
#   rep 10 / fold 2 -- MCC=0.629
#   rep 10 / fold 3 -- MCC=0.510
#   rep 10 / fold 4 -- MCC=0.709
#   rep 10 / fold 5 -- MCC=0.548
#
# [rnCV] XGBoost
#   rep 1 / fold 1 -- MCC=0.633
#   rep 1 / fold 2 -- MCC=0.545
#   rep 1 / fold 3 -- MCC=0.464
#   rep 1 / fold 4 -- MCC=0.669
#   rep 1 / fold 5 -- MCC=0.622
#   rep 2 / fold 1 -- MCC=0.672
#   rep 2 / fold 2 -- MCC=0.461
#   rep 2 / fold 3 -- MCC=0.410
#   rep 2 / fold 4 -- MCC=0.624
#   rep 2 / fold 5 -- MCC=0.334
#   rep 3 / fold 1 -- MCC=0.551
#   rep 3 / fold 2 -- MCC=0.675
#   rep 3 / fold 3 -- MCC=0.574
#   rep 3 / fold 4 -- MCC=0.514
#   rep 3 / fold 5 -- MCC=0.580
#   rep 4 / fold 1 -- MCC=0.633
#   rep 4 / fold 2 -- MCC=0.549
#   rep 4 / fold 3 -- MCC=0.452
#   rep 4 / fold 4 -- MCC=0.583
#   rep 4 / fold 5 -- MCC=0.538
#   rep 5 / fold 1 -- MCC=0.550
#   rep 5 / fold 2 -- MCC=0.593
#   rep 5 / fold 3 -- MCC=0.510
#   rep 5 / fold 4 -- MCC=0.372
#   rep 5 / fold 5 -- MCC=0.580
#   rep 6 / fold 1 -- MCC=0.557
#   rep 6 / fold 2 -- MCC=0.450
#   rep 6 / fold 3 -- MCC=0.503
#   rep 6 / fold 4 -- MCC=0.580
#   rep 6 / fold 5 -- MCC=0.464
#   rep 7 / fold 1 -- MCC=0.431
#   rep 7 / fold 2 -- MCC=0.711
#   rep 7 / fold 3 -- MCC=0.669
#   rep 7 / fold 4 -- MCC=0.548
#   rep 7 / fold 5 -- MCC=0.464
#   rep 8 / fold 1 -- MCC=0.633
#   rep 8 / fold 2 -- MCC=0.474
#   rep 8 / fold 3 -- MCC=0.464
#   rep 8 / fold 4 -- MCC=0.457
#   rep 8 / fold 5 -- MCC=0.669
#   rep 9 / fold 1 -- MCC=0.795
#   rep 9 / fold 2 -- MCC=0.549
#   rep 9 / fold 3 -- MCC=0.495
#   rep 9 / fold 4 -- MCC=0.708
#   rep 9 / fold 5 -- MCC=0.495
#   rep 10 / fold 1 -- MCC=0.467
#   rep 10 / fold 2 -- MCC=0.586
#   rep 10 / fold 3 -- MCC=0.457
#   rep 10 / fold 4 -- MCC=0.709
#   rep 10 / fold 5 -- MCC=0.510
#
# [rnCV] CatBoost
#   rep 1 / fold 1 -- MCC=0.754
#   rep 1 / fold 2 -- MCC=0.684
#   rep 1 / fold 3 -- MCC=0.583
#   rep 1 / fold 4 -- MCC=0.585
#   rep 1 / fold 5 -- MCC=0.624
#   rep 2 / fold 1 -- MCC=0.754
#   rep 2 / fold 2 -- MCC=0.588
#   rep 2 / fold 3 -- MCC=0.543
#   rep 2 / fold 4 -- MCC=0.664
#   rep 2 / fold 5 -- MCC=0.410
#   rep 3 / fold 1 -- MCC=0.556
#   rep 3 / fold 2 -- MCC=0.753
#   rep 3 / fold 3 -- MCC=0.693
#   rep 3 / fold 4 -- MCC=0.503
#   rep 3 / fold 5 -- MCC=0.537
#   rep 4 / fold 1 -- MCC=0.756
#   rep 4 / fold 2 -- MCC=0.670
#   rep 4 / fold 3 -- MCC=0.543
#   rep 4 / fold 4 -- MCC=0.748
#   rep 4 / fold 5 -- MCC=0.580
#   rep 5 / fold 1 -- MCC=0.550
#   rep 5 / fold 2 -- MCC=0.720
#   rep 5 / fold 3 -- MCC=0.510
#   rep 5 / fold 4 -- MCC=0.462
#   rep 5 / fold 5 -- MCC=0.538
#   rep 6 / fold 1 -- MCC=0.800
#   rep 6 / fold 2 -- MCC=0.549
#   rep 6 / fold 3 -- MCC=0.543
#   rep 6 / fold 4 -- MCC=0.669
#   rep 6 / fold 5 -- MCC=0.464
#   rep 7 / fold 1 -- MCC=0.510
#   rep 7 / fold 2 -- MCC=0.918
#   rep 7 / fold 3 -- MCC=0.706
#   rep 7 / fold 4 -- MCC=0.664
#   rep 7 / fold 5 -- MCC=0.427
#   rep 8 / fold 1 -- MCC=0.689
#   rep 8 / fold 2 -- MCC=0.628
#   rep 8 / fold 3 -- MCC=0.585
#   rep 8 / fold 4 -- MCC=0.495
#   rep 8 / fold 5 -- MCC=0.580
#   rep 9 / fold 1 -- MCC=0.838
#   rep 9 / fold 2 -- MCC=0.628
#   rep 9 / fold 3 -- MCC=0.369
#   rep 9 / fold 4 -- MCC=0.756
#   rep 9 / fold 5 -- MCC=0.537
#   rep 10 / fold 1 -- MCC=0.549
#   rep 10 / fold 2 -- MCC=0.797
#   rep 10 / fold 3 -- MCC=0.669
#   rep 10 / fold 4 -- MCC=0.630
#   rep 10 / fold 5 -- MCC=0.558

# %%
rncv.summary(rncv_results)
# Out:
#            MCC_median          MCC_CI  AUC_median          AUC_CI  BA_median  \
# Algorithm
# LR              0.639  [0.615, 0.674]       0.893  [0.875, 0.906]      0.817
# GNB             0.654  [0.610, 0.678]       0.893  [0.878, 0.910]      0.823
# LDA             0.664  [0.623, 0.706]       0.888  [0.883, 0.901]      0.823
# RF              0.624  [0.582, 0.659]       0.885  [0.864, 0.904]      0.802
# LightGBM        0.580  [0.538, 0.602]       0.860  [0.842, 0.888]      0.780
# XGBoost         0.549  [0.507, 0.580]       0.853  [0.842, 0.880]      0.775
# CatBoost        0.586  [0.554, 0.667]       0.884  [0.864, 0.899]      0.794
#
#                     BA_CI  F1_median           F1_CI  Recall_median  \
# Algorithm
# LR         [0.797, 0.830]      0.800  [0.771, 0.814]          0.773
# GNB        [0.798, 0.844]      0.809  [0.773, 0.828]          0.818
# LDA        [0.799, 0.851]      0.800  [0.777, 0.837]          0.773
# RF         [0.785, 0.821]      0.780  [0.756, 0.789]          0.727
# LightGBM   [0.761, 0.799]      0.762  [0.737, 0.780]          0.773
# XGBoost    [0.745, 0.787]      0.753  [0.723, 0.766]          0.773
# CatBoost   [0.775, 0.825]      0.779  [0.753, 0.800]          0.773
#
#                 Recall_CI  Specificity_median  Specificity_CI  \
# Algorithm
# LR         [0.727, 0.801]               0.885  [0.865, 0.923]
# GNB        [0.739, 0.818]               0.846  [0.846, 0.885]
# LDA        [0.727, 0.818]               0.885  [0.846, 0.904]
# RF         [0.682, 0.773]               0.846  [0.846, 0.885]
# LightGBM   [0.696, 0.795]               0.846  [0.808, 0.865]
# XGBoost    [0.727, 0.773]               0.808  [0.778, 0.846]
# CatBoost   [0.727, 0.773]               0.885  [0.846, 0.885]
#
#            Precision_median    Precision_CI  PRAUC_median        PRAUC_CI
# Algorithm
# LR                    0.854  [0.815, 0.876]         0.900  [0.878, 0.911]
# GNB                   0.833  [0.805, 0.850]         0.886  [0.856, 0.900]
# LDA                   0.842  [0.815, 0.868]         0.891  [0.881, 0.911]
# RF                    0.806  [0.789, 0.838]         0.888  [0.859, 0.909]
# LightGBM              0.789  [0.750, 0.810]         0.856  [0.843, 0.886]
# XGBoost               0.757  [0.739, 0.792]         0.861  [0.837, 0.878]
# CatBoost              0.811  [0.795, 0.850]         0.889  [0.857, 0.909]

# %% [markdown]
# ## Compare baseline vs tuned (median MCC)

# %%
import pandas as pd

comparison = pd.DataFrame({
    "Baseline_MCC": {n: df["MCC"].median() for n, df in baseline_results.items()},
    "Tuned_MCC":    {n: df["MCC"].median() for n, df in rncv_results.items()}
})
comparison["Improvement"] = comparison["Tuned_MCC"] - comparison["Baseline_MCC"]
comparison.sort_values("Tuned_MCC", ascending=False)
# Out:
#           Baseline_MCC  Tuned_MCC  Improvement
# LDA           0.664348   0.664342    -0.000006
# GNB           0.653531   0.653531     0.000000
# LR            0.630703   0.638893     0.008190
# RF            0.600003   0.623839     0.023837
# CatBoost      0.581257   0.586456     0.005199
# LightGBM      0.552923   0.579538     0.026615
# XGBoost       0.569405   0.548661    -0.020744

# %% [markdown]
# ## Winner selection
# Pick the algorithm with the highest median MCC. If two are close, look at the bootstrap CIs from the summary table.

# %%
winner = comparison["Tuned_MCC"].idxmax()
print("Winner algorithm:", winner)
print("Median MCC:", round(comparison.loc[winner, "Tuned_MCC"], 3))
# Out:
# Winner algorithm: LDA
# Median MCC: 0.664

# %% [markdown]
# ---
# # Task 4 — Feature Selection with mRMR
#
# We use **mRMR (max Relevance min Redundancy)** as our model-agnostic feature selection method.
#
# **Why mRMR:**
# - Model-agnostic — does not depend on the winner algorithm
# - Handles mixed feature types (continuous + categorical)
# - Penalises redundant features (e.g. `oldpeak`↔`slope` corr=0.60)
#
# Feature selection is applied **inside the outer loop**, fitted on outer-train only → no data leakage.

# %% [markdown]
# ## Step 4.1 — Choose best K
# We try K = 5 to 10 on a quick 3-fold CV using LDA (the winner) and pick the K with the highest MCC.

# %%
best_k, k_results = ncv.choose_best_k(X, y, k_values=[5, 6, 7, 8, 9, 10])
print("Best K selected:", best_k)
# Out:
# K=5 -> MCC=0.675
# K=6 -> MCC=0.676
# K=7 -> MCC=0.668
# K=8 -> MCC=0.659
# K=9 -> MCC=0.667
# K=10 -> MCC=0.659
#
# Best K = 6  (MCC = 0.676)
# Best K selected: 6

# %% [markdown]
# ## Step 4.2 — Run rnCV with mRMR feature selection
# Same pipeline as Task 3 but now mRMR selects the top-K features inside each outer fold.

# %%
# only the winner algorithm (LDA)
estimators_lda   = {"LDA": estimators["LDA"]}
param_spaces_lda = {"LDA": param_spaces["LDA"]}

rncv_fs = ncv.RepeatedNestedCV_FS(
    estimators=estimators_lda,
    param_spaces=param_spaces_lda,
    R=10, N=5, K=3,
    n_trials=50,
    random_state=42,
    k_features=best_k
)

rncv_fs_results = rncv_fs.run(X, y)
# Out:
# [rnCV] LDA
#   rep 1 / fold 1 -- MCC=0.676
#   rep 1 / fold 2 -- MCC=0.635
#   rep 1 / fold 3 -- MCC=0.669
#   rep 1 / fold 4 -- MCC=0.585
#   rep 1 / fold 5 -- MCC=0.664
#   rep 2 / fold 1 -- MCC=0.796
#   rep 2 / fold 2 -- MCC=0.713
#   rep 2 / fold 3 -- MCC=0.623
#   rep 2 / fold 4 -- MCC=0.708
#   rep 2 / fold 5 -- MCC=0.410
#   rep 3 / fold 1 -- MCC=0.594
#   rep 3 / fold 2 -- MCC=0.753
#   rep 3 / fold 3 -- MCC=0.799
#   rep 3 / fold 4 -- MCC=0.680
#   rep 3 / fold 5 -- MCC=0.706
#   rep 4 / fold 1 -- MCC=0.800
#   rep 4 / fold 2 -- MCC=0.711
#   rep 4 / fold 3 -- MCC=0.503
#   rep 4 / fold 4 -- MCC=0.706
#   rep 4 / fold 5 -- MCC=0.413
#   rep 5 / fold 1 -- MCC=0.678
#   rep 5 / fold 2 -- MCC=0.767
#   rep 5 / fold 3 -- MCC=0.792
#   rep 5 / fold 4 -- MCC=0.553
#   rep 5 / fold 5 -- MCC=0.669
#   rep 6 / fold 1 -- MCC=0.717
#   rep 6 / fold 2 -- MCC=0.670
#   rep 6 / fold 3 -- MCC=0.680
#   rep 6 / fold 4 -- MCC=0.664
#   rep 6 / fold 5 -- MCC=0.624
#   rep 7 / fold 1 -- MCC=0.594
#   rep 7 / fold 2 -- MCC=0.918
#   rep 7 / fold 3 -- MCC=0.706
#   rep 7 / fold 4 -- MCC=0.706
#   rep 7 / fold 5 -- MCC=0.453
#   rep 8 / fold 1 -- MCC=0.717
#   rep 8 / fold 2 -- MCC=0.753
#   rep 8 / fold 3 -- MCC=0.548
#   rep 8 / fold 4 -- MCC=0.580
#   rep 8 / fold 5 -- MCC=0.623
#   rep 9 / fold 1 -- MCC=0.756
#   rep 9 / fold 2 -- MCC=0.713
#   rep 9 / fold 3 -- MCC=0.453
#   rep 9 / fold 4 -- MCC=0.664
#   rep 9 / fold 5 -- MCC=0.669
#   rep 10 / fold 1 -- MCC=0.508
#   rep 10 / fold 2 -- MCC=0.837
#   rep 10 / fold 3 -- MCC=0.502
#   rep 10 / fold 4 -- MCC=0.733
#   rep 10 / fold 5 -- MCC=0.585

# %% [markdown]
# ## Step 4.3 — Summary of results with feature selection

# %%
rncv_fs.summary(rncv_fs_results)
# Out:
#            MCC_median          MCC_CI  AUC_median          AUC_CI  BA_median  \
# Algorithm
# LDA             0.673  [0.650, 0.706]       0.893  [0.865, 0.898]      0.832
#
#                     BA_CI  F1_median           F1_CI  Recall_median  \
# Algorithm
# LDA        [0.817, 0.850]       0.81  [0.789, 0.833]          0.783
#
#                 Recall_CI  Specificity_median  Specificity_CI  \
# Algorithm
# LDA        [0.756, 0.818]               0.885  [0.885, 0.906]
#
#            Precision_median    Precision_CI  PRAUC_median        PRAUC_CI
# Algorithm
# LDA                   0.854  [0.833, 0.872]         0.892  [0.860, 0.910]

# %% [markdown]
# ## Step 4.4 — Feature stability
# How often each feature was selected across 50 folds (5 × 10).

# %%
stability = rncv_fs.feature_stability()
print(stability)
# Out:
# thal       100.0
# ca         100.0
# cp          92.0
# sex         92.0
# exang       86.0
# thalach     58.0
# slope       36.0
# oldpeak     24.0
# restecg     12.0
# dtype: float64

# %%
ncv.plot_feature_stability(stability)

# %% [markdown]
# ## Step 4.5 — Compare full features vs selected features

# %%
ncv.compare_full_vs_selected(rncv_results, rncv_fs_results, algorithm="LDA")
# Out:
# Metric            Full (13)     Selected     Diff
# --------------------------------------------------
# MCC                   0.664        0.673   +0.009
# AUC                   0.888        0.893   +0.005
# BA                    0.823        0.832   +0.008
# F1                    0.800        0.810   +0.010
# Recall                0.773        0.783   +0.010
# Specificity           0.885        0.885   +0.000
# Precision             0.842        0.854   +0.011
# PRAUC                 0.891        0.892   +0.001

# %% [markdown]
# **Discussion:**
#
# If the reduced feature set matches or slightly improves performance, this confirms that the dropped features (`fbs`, `chol`, `trestbps`, `restecg`) were noise.
#
# The most stably selected features are expected to be `thal`, `ca`, `cp`, `exang`, `thalach`, `oldpeak` — all clinically meaningful predictors of coronary artery disease.

# %% [markdown]
# ---
# # Task 5 — Train the Final Model

# %% [markdown]
# ## Step 5.1 — Find best hyperparameters using simple 5-fold CV on whole dataset

# %%
best_parameters_full = ncv.find_best_params(
    X            = X,
    y            = y,
    estimator    = estimators["LDA"],
    space_fn     = param_spaces["LDA"],
    n_trials     = 50,
    cv           = 5,
    random_state = 42
)
print("Best hyperparameters:", best_parameters_full)
# Out:
# Best hyperparameters: {'solver': 'lsqr', 'shrinkage': 0.5247564316322378}
# Best hyperparameters: {'solver': 'lsqr', 'shrinkage': 0.5247564316322378}

# %% [markdown]
# ## Step 5.2 — Train final model on all data and save
# The pipeline accepts raw unprocessed input and returns predictions.

# %%
final_pipeline = ncv.save_final_model(X, y, best_parameters_full)
# Out:
# Final model trained on all data.
# Model saved to models/final_model.pkl
# Model loaded back successfully.

# %% [markdown]
# **Sanity check** — load and predict on the first 5 patients.

# %%
import pickle

with open("models/final_model.pkl", "rb") as f:
    loaded = pickle.load(f)

predictions = loaded.predict(X.head())
print("Predictions for first 5 patients:", predictions)
# Out:
# Predictions for first 5 patients: [1 0 0 0 1]

# %% [markdown]
# ## Step 5.3 — SHAP Interpretation
#
# We use `LinearExplainer` because LDA is a linear model.
#
# SHAP values quantify each feature's contribution to individual predictions.

# %%
shap_values, explainer = ncv.compute_shap(final_pipeline, X)

# %% [markdown]
# **Discussion:**
#
# The SHAP values confirm the patterns observed during EDA. Features with the highest mean absolute SHAP values match the strongest Spearman correlations with the target:
#
# - **thal** — reversible defect strongly indicates coronary artery disease
# - **ca** — more blocked vessels = higher disease risk
# - **cp** — asymptomatic chest pain is paradoxically a strong indicator
# - **thalach** — lower max heart rate indicates reduced cardiac function
# - **oldpeak** — ST depression during exercise is a known marker
#
# Weak features such as **fbs**, **chol**, and **trestbps** show low SHAP impact, consistent with their weak EDA correlations.
#
# The LDA model has learned clinically meaningful patterns aligned with established medical knowledge about heart disease risk factors.

# %% [markdown]
# ---
# # Bonus — Error Analysis
#
# Split dataset into train/validation, train on train, analyze errors on validation set.

# %%
fp, fn, correct, val_shap = ncv.error_analysis(X, y, best_parameters_full)
# Out:
# False Positives: 2
# False Negatives: 6
# Correct        : 41
# SHAP summary — validation set:

# %% [markdown]
# ### Inspect false negatives (most clinically dangerous)
# These are patients with heart disease that the model missed.

# %%
fn[eda.features].describe()
# Out:
#              age    trestbps        chol     thalach   oldpeak       sex  fbs  \
# count   6.000000    6.000000    6.000000    6.000000  6.000000  6.000000  6.0
# mean   50.666667  132.666667  231.500000  166.166667  0.666667  0.833333  0.0
# std     9.003703   24.320088   36.757312    9.724539  1.537097  0.408248  0.0
# min    38.000000  110.000000  172.000000  158.000000  0.000000  0.000000  0.0
# 25%    43.750000  114.000000  230.250000  159.250000  0.000000  1.000000  0.0
# 50%    54.500000  125.000000  231.500000  162.000000  0.000000  1.000000  0.0
# 75%    57.000000  148.000000  235.000000  171.500000  0.150000  1.000000  0.0
# max    59.000000  170.000000  288.000000  182.000000  3.800000  1.000000  0.0
#
#           exang        cp   restecg     slope     thal        ca
# count  6.000000  6.000000  6.000000  6.000000  6.00000  6.000000
# mean   0.166667  2.333333  1.333333  1.500000  5.00000  0.500000
# std    0.408248  1.366260  1.032796  0.547723  2.19089  0.547723
# min    0.000000  1.000000  0.000000  1.000000  3.00000  0.000000
# 25%    0.000000  1.250000  0.500000  1.000000  3.00000  0.000000
# 50%    0.000000  2.000000  2.000000  1.500000  5.00000  0.500000
# 75%    0.000000  3.500000  2.000000  2.000000  7.00000  1.000000
# max    1.000000  4.000000  2.000000  2.000000  7.00000  1.000000

# %% [markdown]
# ### Inspect false positives
# These are healthy patients that the model flagged as diseased.

# %%
fp[eda.features].describe()
# Out:
#             age    trestbps        chol     thalach   oldpeak  sex  fbs  \
# count   2.00000    2.000000    2.000000    2.000000  2.000000  2.0  2.0
# mean   55.50000  126.000000  232.500000  157.500000  0.200000  1.0  0.0
# std     2.12132    8.485281   36.062446   14.849242  0.282843  0.0  0.0
# min    54.00000  120.000000  207.000000  147.000000  0.000000  1.0  0.0
# 25%    54.75000  123.000000  219.750000  152.250000  0.100000  1.0  0.0
# 50%    55.50000  126.000000  232.500000  157.500000  0.200000  1.0  0.0
# 75%    56.25000  129.000000  245.250000  162.750000  0.300000  1.0  0.0
# max    57.00000  132.000000  258.000000  168.000000  0.400000  1.0  0.0
#
#           exang        cp   restecg     slope  thal   ca
# count  2.000000  2.000000  2.000000  2.000000   2.0  2.0
# mean   0.500000  3.500000  1.000000  1.500000   7.0  0.0
# std    0.707107  0.707107  1.414214  0.707107   0.0  0.0
# min    0.000000  3.000000  0.000000  1.000000   7.0  0.0
# 25%    0.250000  3.250000  0.500000  1.250000   7.0  0.0
# 50%    0.500000  3.500000  1.000000  1.500000   7.0  0.0
# 75%    0.750000  3.750000  1.500000  1.750000   7.0  0.0
# max    1.000000  4.000000  2.000000  2.000000   7.0  0.0

# %% [markdown]
# ### Clinician-Oriented Report
#
# **How the model makes decisions:**
# The LDA model assigns a heart disease probability based on a weighted combination of clinical features. The most influential features are `thal`, `ca`, `cp`, `exang`, and `thalach`.
#
# **False Negatives (missed diagnoses):**
# Patients with heart disease classified as healthy. These tend to have atypical presentations — borderline thalach values, intermediate `cp` types, or low `oldpeak`. Clinical risk: missed diagnosis can delay treatment.
#
# **False Positives (false alarms):**
# Healthy patients flagged as diseased. These often share features with diseased patients (e.g. high `oldpeak` or `ca`>0). Clinical risk: unnecessary procedures and patient anxiety.
#
# **Limitations:**
# - Small dataset (242 patients) — limited generalisation
# - Trained only on Cleveland Clinic data — different populations may differ
# - Model should assist, not replace, clinical judgment
# - Threshold can be tuned to favour sensitivity (catch more disease) at the cost of specificity
